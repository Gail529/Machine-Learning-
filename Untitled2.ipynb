# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data=pd.read_excel("/content/games2.csv.xlsx")

# %%
data
# Out:
#           id  ...  opening_ply
# 0   TZJHLljE  ...            5
# 1   l1NXvwaE  ...            4
# 2   mIICvQHh  ...            3
# 3   kWKvrqYL  ...            3
# 4   9tXo1AUZ  ...            5
# 5   MsoDV9wj  ...            4
# 6   qwU9rasv  ...           10
# 7   RVN0N3VK  ...            5
# 8   dwF3DJHO  ...            6
# 9   afoMwnLg  ...            4
# 10  HgKLWPsz  ...            1
# 11  Vf5fKWzI  ...            9
# 12  HRti5mKv  ...            3
# 13  2fEjSei6  ...            2
# 14  u7i6dOaJ  ...            8
# 15  guanvMR5  ...            7
# 16  PmpkWkmm  ...            8
# 17  EwaK0IsE  ...            8
# 18  yrSDozT3  ...            5
#
# [19 rows x 16 columns]

# %%
data.head()
# Out:
#   Unnamed: 0 Unnamed: 1  ...                             Unnamed: 14  Unnamed: 15
# 0         id      rated  ...                            opening_name  opening_ply
# 1   TZJHLljE      False  ...        Slav Defense: Exchange Variation            5
# 2   l1NXvwaE       True  ...  Nimzowitsch Defense: Kennedy Variation            4
# 3   mIICvQHh       True  ...   King's Pawn Game: Leonardis Variation            3
# 4   kWKvrqYL       True  ...  Queen's Pawn Game: Zukertort Variation            3
#
# [5 rows x 16 columns]

# %%
data = np.random.rand(50, 16)
ax = sns.heatmap(data, linewidth=0.5)
plt.show()

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
data.shape
# Out:
# (50, 16)

# %%
col=data.iloc [0,1,4,5,6,9,11]]
# Out:
#   File "<ipython-input-27-86cfc8c50cdb>", line 1
#     col=data.iloc [0,1,4,5,6,9,11]]
#                                   ^
# SyntaxError: invalid syntax

# %%
x= data.iloc[8].values

# %%
data_pd = pd.DataFrame(data)

# %%
data
# Out:
#    Unnamed: 0  ...  Unnamed: 15
# 0          id  ...  opening_ply
# 1    TZJHLljE  ...            5
# 2    l1NXvwaE  ...            4
# 3    mIICvQHh  ...            3
# 4    kWKvrqYL  ...            3
# 5    9tXo1AUZ  ...            5
# 6    MsoDV9wj  ...            4
# 7    qwU9rasv  ...           10
# 8    RVN0N3VK  ...            5
# 9    dwF3DJHO  ...            6
# 10   afoMwnLg  ...            4
# 11   HgKLWPsz  ...            1
# 12   Vf5fKWzI  ...            9
# 13   HRti5mKv  ...            3
# 14   2fEjSei6  ...            2
# 15   u7i6dOaJ  ...            8
# 16   guanvMR5  ...            7
# 17   PmpkWkmm  ...            8
# 18   EwaK0IsE  ...            8
# 19   yrSDozT3  ...            5
# 20   x31mXlvc  ...            2
# 21   oQklnWWp  ...            6
# 22   QFCZwY1f  ...            2
# 23   5cgBygpI  ...            3
# 24   UhXXBOMY  ...            4
# 25   mCij4hBq  ...            3
# 26   ifUMWtVj  ...            4
# 27   Wf0zuLQQ  ...            8
# ...

# %%
data_pd.rename(columns = {'0':'id'})
# Out:
#           0         1         2   ...        13        14        15
# 0   0.694635  0.404106  0.824137  ...  0.590843  0.966685  0.564714
# 1   0.081027  0.226994  0.382106  ...  0.407456  0.177352  0.381752
# 2   0.504145  0.749681  0.500952  ...  0.129668  0.531331  0.571373
# 3   0.919667  0.080708  0.973357  ...  0.400386  0.249793  0.187064
# 4   0.785658  0.109238  0.240894  ...  0.113532  0.970416  0.832503
# 5   0.549055  0.634753  0.051341  ...  0.949057  0.115458  0.770747
# 6   0.866666  0.187817  0.844706  ...  0.593785  0.591155  0.025933
# 7   0.166476  0.418888  0.241538  ...  0.712998  0.758439  0.996484
# 8   0.106833  0.869085  0.212646  ...  0.230145  0.790652  0.861835
# 9   0.871659  0.376118  0.837884  ...  0.223798  0.817631  0.587613
# 10  0.761702  0.716462  0.422228  ...  0.356283  0.483203  0.171679
# 11  0.851765  0.704094  0.680432  ...  0.510207  0.332894  0.130279
# 12  0.117635  0.748492  0.368558  ...  0.572962  0.909307  0.242284
# ...

# %%
x= data_pd.iloc[9,11]

# %%
data_pd
# Out:
#           0         1         2   ...        13        14        15
# 0   0.694635  0.404106  0.824137  ...  0.590843  0.966685  0.564714
# 1   0.081027  0.226994  0.382106  ...  0.407456  0.177352  0.381752
# 2   0.504145  0.749681  0.500952  ...  0.129668  0.531331  0.571373
# 3   0.919667  0.080708  0.973357  ...  0.400386  0.249793  0.187064
# 4   0.785658  0.109238  0.240894  ...  0.113532  0.970416  0.832503
# 5   0.549055  0.634753  0.051341  ...  0.949057  0.115458  0.770747
# 6   0.866666  0.187817  0.844706  ...  0.593785  0.591155  0.025933
# 7   0.166476  0.418888  0.241538  ...  0.712998  0.758439  0.996484
# 8   0.106833  0.869085  0.212646  ...  0.230145  0.790652  0.861835
# 9   0.871659  0.376118  0.837884  ...  0.223798  0.817631  0.587613
# 10  0.761702  0.716462  0.422228  ...  0.356283  0.483203  0.171679
# 11  0.851765  0.704094  0.680432  ...  0.510207  0.332894  0.130279
# 12  0.117635  0.748492  0.368558  ...  0.572962  0.909307  0.242284
# ...

# %%
x=data_pd.iloc[11]

# %%
b=data_pd.iloc[4]

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,train_y,test_x,test_y=train_test_split(x,b,test_size=0.2,random_state=123)

# %%
from sklearn.linear_model  import LinearRegression

# %%
lr=LinearRegression()

# %%
data_pd.drop(columns=['Unnamed: 5'])
# Out:
#    Unnamed: 0  ...  Unnamed: 15
# 0          id  ...  opening_ply
# 1    TZJHLljE  ...            5
# 2    l1NXvwaE  ...            4
# 3    mIICvQHh  ...            3
# 4    kWKvrqYL  ...            3
# 5    9tXo1AUZ  ...            5
# 6    MsoDV9wj  ...            4
# 7    qwU9rasv  ...           10
# 8    RVN0N3VK  ...            5
# 9    dwF3DJHO  ...            6
# 10   afoMwnLg  ...            4
# 11   HgKLWPsz  ...            1
# 12   Vf5fKWzI  ...            9
# 13   HRti5mKv  ...            3
# 14   2fEjSei6  ...            2
# 15   u7i6dOaJ  ...            8
# 16   guanvMR5  ...            7
# 17   PmpkWkmm  ...            8
# 18   EwaK0IsE  ...            8
# 19   yrSDozT3  ...            5
# 20   x31mXlvc  ...            2
# 21   oQklnWWp  ...            6
# 22   QFCZwY1f  ...            2
# 23   5cgBygpI  ...            3
# 24   UhXXBOMY  ...            4
# 25   mCij4hBq  ...            3
# 26   ifUMWtVj  ...            4
# 27   Wf0zuLQQ  ...            8
# ...

# %%
lr.fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-3e39cd206a76> in <module>()
# ----> 1 lr.fit(train_x,train_y)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# ...

# %%
data
# Out:
#    Unnamed: 0  ...  Unnamed: 15
# 0          id  ...  opening_ply
# 1    TZJHLljE  ...            5
# 2    l1NXvwaE  ...            4
# 3    mIICvQHh  ...            3
# 4    kWKvrqYL  ...            3
# 5    9tXo1AUZ  ...            5
# 6    MsoDV9wj  ...            4
# 7    qwU9rasv  ...           10
# 8    RVN0N3VK  ...            5
# 9    dwF3DJHO  ...            6
# 10   afoMwnLg  ...            4
# 11   HgKLWPsz  ...            1
# 12   Vf5fKWzI  ...            9
# 13   HRti5mKv  ...            3
# 14   2fEjSei6  ...            2
# 15   u7i6dOaJ  ...            8
# 16   guanvMR5  ...            7
# 17   PmpkWkmm  ...            8
# 18   EwaK0IsE  ...            8
# 19   yrSDozT3  ...            5
# 20   x31mXlvc  ...            2
# 21   oQklnWWp  ...            6
# 22   QFCZwY1f  ...            2
# 23   5cgBygpI  ...            3
# 24   UhXXBOMY  ...            4
# 25   mCij4hBq  ...            3
# 26   ifUMWtVj  ...            4
# 27   Wf0zuLQQ  ...            8
# ...

# %%
data_pd['Unnamed: 5'] = data_pd['Unnamed: 5'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-a873180007d5> in <module>()
# ----> 1 data_pd['Unnamed: 5'] = data_pd['Unnamed: 5'].astype(float)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
data_pd.head()
# Out:
#   Unnamed: 0 Unnamed: 1  ...                             Unnamed: 14  Unnamed: 15
# 0         id      rated  ...                            opening_name  opening_ply
# 1   TZJHLljE      False  ...        Slav Defense: Exchange Variation            5
# 2   l1NXvwaE       True  ...  Nimzowitsch Defense: Kennedy Variation            4
# 3   mIICvQHh       True  ...   King's Pawn Game: Leonardis Variation            3
# 4   kWKvrqYL       True  ...  Queen's Pawn Game: Zukertort Variation            3
#
# [5 rows x 16 columns]

# %%
data.head()
# Out:
#   Unnamed: 0 Unnamed: 1  ...                             Unnamed: 14  Unnamed: 15
# 0         id      rated  ...                            opening_name  opening_ply
# 1   TZJHLljE      False  ...        Slav Defense: Exchange Variation            5
# 2   l1NXvwaE       True  ...  Nimzowitsch Defense: Kennedy Variation            4
# 3   mIICvQHh       True  ...   King's Pawn Game: Leonardis Variation            3
# 4   kWKvrqYL       True  ...  Queen's Pawn Game: Zukertort Variation            3
#
# [5 rows x 16 columns]

# %%
data_pd.drop(columns=['Unnamed: 5'])
# Out:
#    Unnamed: 0  ...  Unnamed: 15
# 0          id  ...  opening_ply
# 1    TZJHLljE  ...            5
# 2    l1NXvwaE  ...            4
# 3    mIICvQHh  ...            3
# 4    kWKvrqYL  ...            3
# 5    9tXo1AUZ  ...            5
# 6    MsoDV9wj  ...            4
# 7    qwU9rasv  ...           10
# 8    RVN0N3VK  ...            5
# 9    dwF3DJHO  ...            6
# 10   afoMwnLg  ...            4
# 11   HgKLWPsz  ...            1
# 12   Vf5fKWzI  ...            9
# 13   HRti5mKv  ...            3
# 14   2fEjSei6  ...            2
# 15   u7i6dOaJ  ...            8
# 16   guanvMR5  ...            7
# 17   PmpkWkmm  ...            8
# 18   EwaK0IsE  ...            8
# 19   yrSDozT3  ...            5
# 20   x31mXlvc  ...            2
# 21   oQklnWWp  ...            6
# 22   QFCZwY1f  ...            2
# 23   5cgBygpI  ...            3
# 24   UhXXBOMY  ...            4
# 25   mCij4hBq  ...            3
# 26   ifUMWtVj  ...            4
# 27   Wf0zuLQQ  ...            8
# ...

# %%
lr.fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-3e39cd206a76> in <module>()
# ----> 1 lr.fit(train_x,train_y)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# ...
