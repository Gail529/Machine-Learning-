# %% [markdown]
# <a href="https://colab.research.google.com/github/Gail529/Machine-Learning-/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("/content/games.csv")

# %%
data
# Out:
#     turns  ... opening_ply
# 0      13  ...           5
# 1      16  ...           4
# 2      61  ...           3
# 3      61  ...           3
# 4      95  ...           5
# ..    ...  ...         ...
# 94     62  ...           4
# 95     85  ...           2
# 96     38  ...           5
# 97     14  ...           8
# 98    113  ...           4
#
# [99 rows x 12 columns]

# %%
data.head()
# Out:
#   Unnamed: 0 Unnamed: 1  ...                             Unnamed: 14  Unnamed: 15
# 0         id      rated  ...                            opening_name  opening_ply
# 1   TZJHLljE      False  ...        Slav Defense: Exchange Variation            5
# 2   l1NXvwaE       True  ...  Nimzowitsch Defense: Kennedy Variation            4
# 3   mIICvQHh       True  ...   King's Pawn Game: Leonardis Variation            3
# 4   kWKvrqYL       True  ...  Queen's Pawn Game: Zukertort Variation            3
#
# [5 rows x 16 columns]

# %%
data = np.random.rand(50, 16)
ax = sns.heatmap(data, linewidth=0.5)
plt.show()

# %%
data.columns
# Out:
# Index(['turns', 'victory_status', 'winner', 'increment_code', 'white_id',
#        'white_rating', 'black_id', 'black_rating', 'moves', 'opening_eco',
#        'opening_name', 'opening_ply'],
#       dtype='object')

# %%
data.shape
# Out:
# (50, 16)

# %%
x= data.iloc[8].values

# %%
data_pd = pd.DataFrame(data)

# %%
data_pd
# Out:
#     turns  ...  opening_name_Zukertort Opening: Ross Gambit
# 0      13  ...                                            0
# 1      16  ...                                            0
# 2      61  ...                                            0
# 3      61  ...                                            0
# 4      95  ...                                            0
# ..    ...  ...                                          ...
# 94     62  ...                                            0
# 95     85  ...                                            0
# 96     38  ...                                            0
# 97     14  ...                                            0
# 98    113  ...                                            0
#
# [99 rows x 356 columns]

# %%
data_pd.rename(columns = {'0':'id'})
# Out:
#     turns  ...  opening_name_Zukertort Opening: Ross Gambit
# 0      13  ...                                            0
# 1      16  ...                                            0
# 2      61  ...                                            0
# 3      61  ...                                            0
# 4      95  ...                                            0
# ..    ...  ...                                          ...
# 94     62  ...                                            0
# 95     85  ...                                            0
# 96     38  ...                                            0
# 97     14  ...                                            0
# 98    113  ...                                            0
#
# [99 rows x 356 columns]

# %%
data = pd.get_dummies(data_pd)

# %%
data
# Out:
#     turns  ...  opening_name_Zukertort Opening: Ross Gambit
# 0      13  ...                                            0
# 1      16  ...                                            0
# 2      61  ...                                            0
# 3      61  ...                                            0
# 4      95  ...                                            0
# ..    ...  ...                                          ...
# 94     62  ...                                            0
# 95     85  ...                                            0
# 96     38  ...                                            0
# 97     14  ...                                            0
# 98    113  ...                                            0
#
# [99 rows x 356 columns]

# %%
x=data[:,1:3]

# %%
x
# Out:
# array([[1500, 1191,    5],
#        [1322, 1261,    4],
#        [1496, 1500,    3],
#        [1439, 1454,    3],
#        [1523, 1469,    5],
#        [1250, 1002,    4],
#        [1520, 1423,   10],
#        [1413, 2108,    5],
#        [1439, 1392,    6],
#        [1381, 1209,    4],
#        [1381, 1272,    1],
#        [1381, 1867,    9],
#        [1381, 1936,    3],
#        [1381, 1607,    2],
#        [1094, 1141,    8],
#        [1141, 1094,    7],
#        [1094, 1141,    8],
#        [1141, 1094,    8],
#        [1094, 1300,    5],
#        [1500, 1094,    2],
#        [1094, 1676,    6],
#        [1094, 1068,    2],
#        [1500, 1094,    3],
#        [1307, 1106,    4],
#        [1113, 1423,    3],
#        [1078, 1219,    4],
#        [1825, 1079,    8],
#        [1328, 1038,    4],
#        [1056, 1156,    4],
#        [1077, 1148,    4],
#        [1358, 1036,    3],
#        [1200, 1002,    6],
#        [1203, 1019,    3],
#        [1019, 1500,    6],
# ...

# %%
b=data[:,6]

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_b,test_b=train_test_split(x,b,train_size=0.8,test_size=0.2)

# %%
from sklearn.linear_model  import LinearRegression

# %%
lr=LinearRegression()

# %%
data=data.reshape((99,356))

# %%
lr.fit(train_x,train_b)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
b_pred=lr.predict(test_x)

# %%
b_pred
# Out:
# array([0.02233302, 0.02432532, 0.00673522, 0.01851872, 0.02043206,
#        0.00806386, 0.0209948 , 0.01026408, 0.00813746, 0.01052669,
#        0.00357778, 0.02043206, 0.00761305, 0.00734707, 0.01518512,
#        0.00770049, 0.00812805, 0.01878133, 0.00781719, 0.0226826 ])

# %%
from sklearn.metrics import confusion_matrix

# %%
conf=confusion_matrix(test_b,b_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-e36564bc6972> in <module>()
# ----> 1 conf=confusion_matrix(test_b,b_pred)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
# ...

# %%
train_x.shape
# Out:
# (49, 2)

# %%
train_b.shape
# Out:
# (50, 2)
